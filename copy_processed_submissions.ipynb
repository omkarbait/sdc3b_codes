# %%
import os
import shutil
import warnings

def organize_files_by_team(source_dir, root_dir, team_suffix="_1D"):
    """
    Copies files from source_dir to team-specific subdirectories in root_dir.

    Parameters:
    - source_dir (str): Directory containing the original files.
    - root_dir (str): Directory containing the subdirectories for each team.
    - team_suffix (str): String suffix that indicates the end of the team name.
    """
    for filename in os.listdir(source_dir):
        if team_suffix in filename:
            team_name = filename.split(team_suffix)[0]
            team_dir = os.path.join(root_dir, team_name)

            if not os.path.isdir(team_dir):
                warnings.warn(f"Directory not found for team '{team_name}': {team_dir}")
                continue

            src_file = os.path.join(source_dir, filename)
            dst_file = os.path.join(team_dir, filename)

            shutil.copy2(src_file, dst_file)
            print(f"Copied: {filename} → {team_dir}")

# %%
# Example usage:
source_directory = "/Users/omkar.bait/work/SDC/sdc3b/submission_analysis/plots"
destination_root = "/Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/"
suffix_to_identify_team = "_1D"

organize_files_by_team(source_directory, destination_root, suffix_to_identify_team)
# Out:
# Copied: Shuimu-Tianlai-A_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Shuimu-Tianlai-A
# Copied: ToSKA-SBI_general_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/ToSKA-SBI_general
# Copied: Modern_SEarCH_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Modern_SEarCH
# Copied: LoreliB_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/LoreliB
# Copied: Shuimu-Tianlai-A_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Shuimu-Tianlai-A
# Copied: ToSKA-SBI_general_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/ToSKA-SBI_general
# Copied: Modern_SEarCH_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Modern_SEarCH
# Copied: LoreliB_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/LoreliB
# Copied: KUSANAGI_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/KUSANAGI
# Copied: Shuimu-Tianlai-B_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Shuimu-Tianlai-B
# Copied: LoreliA_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/LoreliA
# Copied: KUSANAGI_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/KUSANAGI
# Copied: Shuimu-Tianlai-B_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Shuimu-Tianlai-B
# Copied: LoreliA_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/LoreliA
# Copied: HIstorians_LCDM-Bayesian_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/HIstorians_LCDM-Bayesian
# Copied: HIMALAYA_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/HIMALAYA
# Copied: Imperial-Nottingham_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Imperial-Nottingham
# Copied: RISE_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/RISE
# Copied: 21_To_Infinities_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/21_To_Infinities
# Copied: Akashganga_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Akashganga
# Copied: HIstorians_LCDM-Bayesian_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/HIstorians_LCDM-Bayesian
# Copied: Team_SKAO_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Team_SKAO
# Copied: HIMALAYA_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/HIMALAYA
# Copied: RISE_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/RISE
# Copied: Imperial-Nottingham_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Imperial-Nottingham
# Copied: 21_To_Infinities_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/21_To_Infinities
# Copied: Akashganga_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Akashganga
# Copied: ReionYuga_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/ReionYuga
# Copied: ToSKA-Explicit_likelihood_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/ToSKA-Explicit_likelihood
# Copied: COTSS-21_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/COTSS-21
# Copied: Insight_of_Cosmic_Reionization_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Insight_of_Cosmic_Reionization
# Copied: HIstorians_GPR_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/HIstorians_GPR
# Copied: ReionYuga_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/ReionYuga
# Copied: ToSKA-Explicit_likelihood_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/ToSKA-Explicit_likelihood
# Copied: COTSS-21_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/COTSS-21
# Copied: Insight_of_Cosmic_Reionization_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Insight_of_Cosmic_Reionization
# Copied: HIstorians_GPR_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/HIstorians_GPR
# Copied: YEYE_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/YEYE
# Copied: Cantabrigians_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Cantabrigians
# Copied: ERWA_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/ERWA
# Copied: YEYE_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/YEYE
# Copied: Cantabrigians_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Cantabrigians
# Copied: ERWA_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/ERWA
# Copied: STHENO_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/STHENO
# Copied: EoR-PIE_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/EoR-PIE
# Copied: STHENO_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/STHENO
# Copied: EoR-PIE_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/EoR-PIE
# Copied: Shuimu-Tianlai-C_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Shuimu-Tianlai-C
# Copied: ToSKA-SBI_focused_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/ToSKA-SBI_focused
# Copied: ToSKA-SBI_focused_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/ToSKA-SBI_focused
# Copied: Shuimu-Tianlai-C_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Shuimu-Tianlai-C
# Copied: Traditional_SEarCH_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Traditional_SEarCH
# Copied: EoR-PIE-MC_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/EoR-PIE-MC
# Copied: HIstorians_ANN_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/HIstorians_ANN
# Copied: Traditional_SEarCH_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/Traditional_SEarCH
# Copied: EoR-PIE-MC_1D_projection_linear_PS1.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/EoR-PIE-MC
# Copied: HIstorians_ANN_1D_projection_linear_PS2.jpg → /Users/omkar.bait/work/SDC/sdc3b/submission_analysis/final_submissions_copy/validated_submissions/PS1/team_folders/HIstorians_ANN
